# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/venky73/spam-mails-dataset")
# Out:
# Skipping, found downloaded files in "./spam-mails-dataset" (use force=True to force download)

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/spam-mails-dataset/spam_ham_dataset.csv")

# %%
data.head(5)
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
data.tail(5)
# Out:
#       Unnamed: 0 label                                               text  \
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num
# 5166          0
# 5167          0
# 5168          0
# 5169          0
# 5170          1

# %%
data["text"][5167]
# Out:
# "Subject: 3 / 4 / 2000 and following noms\r\nhpl can ' t take the extra 15 mmcf / d over the weekend . we ' ll try next week ,\r\nbut for now the nom will stay at 60 mmcf / d , with redeliveries as they have\r\nbeen\r\n-\r\n50 into pg & e , 7 from fcv , and 3 at carthage .\r\n- - - - - - - - - - - - - - - - - - - - - - forwarded by bruce mcmills / ftworth / pefs / pec on\r\n03 / 03 / 2000\r\n09 : 42 am - - - - - - - - - - - - - - - - - - - - - - - - - - -\r\nbruce mcmills\r\n03 / 03 / 2000 09 : 10 am\r\nto : dfarmer @ enron . com , briley @ enron . com , stacey . neuweiler @ enron . com\r\ncc : chad w . cass / gcs / cec / pec @ pec , william e . speckels / gcs / cec / pec @ pec , donna\r\nc . spencer / gcs / cec / pec @ pec , michael r . cherry / easttexas / pefs / pec @ pec ,\r\ndarrel f . bane / easttexas / pefs / pec @ pec\r\nsubject : 3 / 4 / 2000 and following noms\r\nthis is to nominate 75 , 000 mmbtu / d into eastrans for 3 / 4 / 2000 and following .\r\nwe will deliver 50 , 00
# ...

# %%
data.shape
# Out:
# (5171, 4)

# %%
import pandas as pd
import re
import nltk
import contractions
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download necessary NLTK resources
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def clean_text(text):
    if pd.isna(text):  # Handle NaN values
        return ""
    text = text.lower()  # Convert to lowercase
    text = re.sub(r"[^a-zA-Z\s]", " ", text)  # Remove special characters & numbers
    text = contractions.fix(text)  # Expand contractions
    tokens = word_tokenize(text)  # Tokenize
    stop_words = set(stopwords.words("english"))  # Load stop words
    # Remove stop words
    for word in tokens:
      if word in stop_words:
        tokens.remove(word)
    return " ".join(tokens)  # Convert tokens back to string

# Apply cleaning function to the entire "text" column
data["text"] = data["text"].apply(clean_text)

# Print cleaned text column
print(data["text"])
# Out:
# 0       subject enron methanol meter follow note gave ...
# 1       subject hpl nom january see attached file hpln...
# 2       subject neon retreat ho ho ho around wonderful...
# 3       subject photoshop windows office cheap main tr...
# 4       subject indian springs deal book teco pvr reve...
#                               ...
# 5166    subject put ft transport volumes decreased sho...
# 5167    subject following noms hpl t take extra mmcf o...
# 5168    subject calpine daily gas nomination julie men...
# 5169    subject industrial worksheets august activity ...
# 5170    subject important online banking alert dear va...
# Name: text, Length: 5171, dtype: object

# %%
print(data)
# Out:
#       Unnamed: 0 label                                               text  \
# 0            605   ham  subject enron methanol meter follow note gave ...
# 1           2349   ham  subject hpl nom january see attached file hpln...
# 2           3624   ham  subject neon retreat ho ho ho around wonderful...
# 3           4685  spam  subject photoshop windows office cheap main tr...
# 4           2030   ham  subject indian springs deal book teco pvr reve...
# ...          ...   ...                                                ...
# 5166        1518   ham  subject put ft transport volumes decreased sho...
# 5167         404   ham  subject following noms hpl t take extra mmcf o...
# 5168        2933   ham  subject calpine daily gas nomination julie men...
# 5169        1409   ham  subject industrial worksheets august activity ...
# 5170        4807  spam  subject important online banking alert dear va...
#
#       label_num
# 0             0
# 1             0
# 2             0
# ...

# %%
data['text'][5167]
# Out:
# 'subject following noms hpl t take extra mmcf over weekend ll try next week the nom stay mmcf with redeliveries they been pg e fcv carthage forwarded bruce mcmills ftworth pefs pec bruce mcmills am dfarmer enron com briley enron com stacey neuweiler enron com cc chad w cass gcs cec pec pec william e speckels gcs cec pec pec donna c spencer gcs cec pec pec michael cherry easttexas pefs pec pec darrel f bane easttexas pefs pec pec subject following noms is to nominate mmbtu eastrans for following will deliver into pg e fuel cotton valley continue mmbtu sale and mmbtu into cartwheel agreement at carthage'

# %%
x = data['text'].values
y = data["label_num"].values

# %%
x
# Out:
# array(['subject enron methanol meter follow note gave on monday preliminary flow data provided daren please override pop daily volume presently zero to reflect daily activity can obtain gas control change is needed soon possible economics purposes',
#        'subject hpl nom january see attached file hplnol xls hplnol xls',
# ...

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer=TfidfVectorizer()

# %%
vectorizer.fit(x)
# Out:
# TfidfVectorizer()

# %%
x=vectorizer.transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (4136, 45680)

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
train_acc=model.predict(x_train)
train_accc=accuracy_score(y_train,train_acc)
print("Training accuracy is:",train_accc)
# Out:
# Training accuracy is: 0.995164410058027

# %%
y_pred=model.predict(x_test)
test_acc=accuracy_score(y_test,y_pred)
print("Testing accuracy is:",test_acc)
# Out:
# Testing accuracy is: 0.9874396135265701

# %%
Input_data = input("Enter the mail:")
Input_data = clean_text(Input_data) # Apply the cleaning function
Input_data = vectorizer.transform([Input_data]) # Transform the cleaned input using the same vectorizer

# Now you can predict
prediction = model.predict(Input_data)
print(prediction)
if prediction[0] == 1:
  print("Spam mail")
else:
  print("Ham mail")
# Out:
# Enter the mail:Reminder: Your meeting with the finance team is scheduled for 3 PM tomorrow.
# [0]
# Ham mail
